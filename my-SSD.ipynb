# %%
import cv2
import keras
from keras.applications.imagenet_utils import preprocess_input
from keras.backend.tensorflow_backend import set_session
from keras.models import Model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import imread
import tensorflow as tf

from ssd import SSD300
from ssd_utils import BBoxUtility

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 8)
plt.rcParams['image.interpolation'] = 'nearest'

np.set_printoptions(suppress=True)

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.45
set_session(tf.Session(config=config))
# Out:
# C:\tools\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
voc_classes = ['Aeroplane', 'Bicycle', 'Bird', 'Boat', 'Bottle',
               'Bus', 'Car', 'Cat', 'Chair', 'Cow', 'Diningtable',
               'Dog', 'Horse','Motorbike', 'Person', 'Pottedplant',
               'Sheep', 'Sofa', 'Train', 'Tvmonitor']
NUM_CLASSES = len(voc_classes) + 1

# %%
input_shape=(300, 300, 3)
model = SSD300(input_shape, num_classes=NUM_CLASSES)
model.load_weights('weights_SSD300.hdf5', by_name=True)
bbox_util = BBoxUtility(NUM_CLASSES)
# Out:
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="conv1_1", padding="same", activation="relu")`
#   name='conv1_1')(net['input'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), name="conv1_2", padding="same", activation="relu")`
#   name='conv1_2')(net['conv1_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:46: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool1", padding="same", strides=(2, 2))`
#   name='pool1')(net['conv1_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:51: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), name="conv2_1", padding="same", activation="relu")`
#   name='conv2_1')(net['pool1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), name="conv2_2", padding="same", activation="relu")`
#   name='conv2_2')(net['conv2_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:57: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool2", padding="same", strides=(2, 2))`
#   name='pool2')(net['conv2_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:62: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_1", padding="same", activation="relu")`
#   name='conv3_1')(net['pool2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:66: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_2", padding="same", activation="relu")`
#   name='conv3_2')(net['conv3_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), name="conv3_3", padding="same", activation="relu")`
#   name='conv3_3')(net['conv3_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:72: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool3", padding="same", strides=(2, 2))`
#   name='pool3')(net['conv3_3'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_1", padding="same", activation="relu")`
#   name='conv4_1')(net['pool3'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:81: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_2", padding="same", activation="relu")`
#   name='conv4_2')(net['conv4_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:85: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv4_3", padding="same", activation="relu")`
#   name='conv4_3')(net['conv4_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:87: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((2, 2), name="pool4", padding="same", strides=(2, 2))`
#   name='pool4')(net['conv4_3'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:92: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_1", padding="same", activation="relu")`
#   name='conv5_1')(net['pool4'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:96: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_2", padding="same", activation="relu")`
#   name='conv5_2')(net['conv5_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:100: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), name="conv5_3", padding="same", activation="relu")`
#   name='conv5_3')(net['conv5_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:102: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D((3, 3), name="pool5", padding="same", strides=(1, 1))`
#   name='pool5')(net['conv5_3'])
# C:\tools\Anaconda3\envs\tensorflow\lib\site-packages\keras\legacy\layers.py:761: UserWarning: The `AtrousConvolution2D` layer  has been deprecated. Use instead the `Conv2D` layer with the `dilation_rate` argument.
#   warnings.warn('The `AtrousConvolution2D` layer '
# C:\tools\Anaconda3\envs\tensorflow\lib\site-packages\keras\legacy\layers.py:765: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (3, 3), name="fc6", padding="same", dilation_rate=(6, 6), activation="relu")`
#   return Conv2D(*args, **kwargs)
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:110: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), name="fc7", padding="same", activation="relu")`
#   border_mode='same', name='fc7')(net['fc6'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:115: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), name="conv6_1", padding="same", activation="relu")`
#   name='conv6_1')(net['fc7'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same", activation="relu", name="conv6_2", strides=(2, 2))`
#   name='conv6_2')(net['conv6_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:122: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv7_1", padding="same", activation="relu")`
#   name='conv7_1')(net['conv6_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:126: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="valid", activation="relu", name="conv7_2", strides=(2, 2))`
#   name='conv7_2')(net['conv7_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:130: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv8_1", padding="same", activation="relu")`
#   name='conv8_1')(net['conv7_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:133: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same", activation="relu", name="conv8_2", strides=(2, 2))`
#   name='conv8_2')(net['conv8_1'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:140: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(12, (3, 3), name="conv4_3_norm_mbox_loc", padding="same")`
#   name='conv4_3_norm_mbox_loc')(net['conv4_3_norm'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:148: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(63, (3, 3), name="conv4_3_norm_mbox_conf", padding="same")`
#   name=name)(net['conv4_3_norm'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:160: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="fc7_mbox_loc", padding="same")`
#   name='fc7_mbox_loc')(net['fc7'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:168: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="fc7_mbox_conf", padding="same")`
#   name=name)(net['fc7'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:178: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv6_2_mbox_loc", padding="same")`
#   name='conv6_2_mbox_loc')(net['conv6_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:186: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv6_2_mbox_conf", padding="same")`
#   name=name)(net['conv6_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:197: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv7_2_mbox_loc", padding="same")`
#   name='conv7_2_mbox_loc')(net['conv7_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:205: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv7_2_mbox_conf", padding="same")`
#   name=name)(net['conv7_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:216: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), name="conv8_2_mbox_loc", padding="same")`
#   name='conv8_2_mbox_loc')(net['conv8_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:224: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(126, (3, 3), name="conv8_2_mbox_conf", padding="same")`
#   name=name)(net['conv8_2'])
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:258: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   mode='concat', concat_axis=1, name='mbox_loc')
# C:\tools\Anaconda3\envs\tensorflow\lib\site-packages\keras\legacy\layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:265: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   mode='concat', concat_axis=1, name='mbox_conf')
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:273: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name='mbox_priorbox')
# C:\tools\emacs\anaconda_workspace\ssd_keras-master\ssd.py:288: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name='predictions')

# %%
import os
input_data_path = './pics/'
inputs = []
images = []

file_list = os.listdir(input_data_path)
for file_name in file_list:
    img_path = input_data_path + file_name
    img = image.load_img(img_path, target_size=(300, 300))
    img = image.img_to_array(img)
    images.append(imread(img_path))
    inputs.append(img.copy())

inputs = preprocess_input(np.array(inputs))
# Out:
# C:\tools\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
preds = model.predict(inputs, batch_size=1, verbose=1)
# Out:
# 13/13 [==============================] - 33s 3s/step

# %%
results = bbox_util.detection_out(preds)

# %%
# %%time
a = model.predict(inputs, batch_size=1)
b = bbox_util.detection_out(preds)
# Out:
# Wall time: 30.8 s

# %%
for i, img in enumerate(images):
    # Parse the outputs.
    det_label = results[i][:, 0]
    det_conf = results[i][:, 1]
    det_xmin = results[i][:, 2]
    det_ymin = results[i][:, 3]
    det_xmax = results[i][:, 4]
    det_ymax = results[i][:, 5]

    # Get detections with confidence higher than 0.6.
    top_indices = [i for i, conf in enumerate(det_conf) if conf >= 0.6]

    top_conf = det_conf[top_indices]
    top_label_indices = det_label[top_indices].tolist()
    top_xmin = det_xmin[top_indices]
    top_ymin = det_ymin[top_indices]
    top_xmax = det_xmax[top_indices]
    top_ymax = det_ymax[top_indices]

    colors = plt.cm.hsv(np.linspace(0, 1, 21)).tolist()

    plt.imshow(img / 255.)
    currentAxis = plt.gca()

    for i in range(top_conf.shape[0]):
        xmin = int(round(top_xmin[i] * img.shape[1]))
        ymin = int(round(top_ymin[i] * img.shape[0]))
        xmax = int(round(top_xmax[i] * img.shape[1]))
        ymax = int(round(top_ymax[i] * img.shape[0]))
        score = top_conf[i]
        label = int(top_label_indices[i])
        label_name = voc_classes[label - 1]
        display_txt = '{:0.2f}, {}'.format(score, label_name)
        coords = (xmin, ymin), xmax-xmin+1, ymax-ymin+1
        color = colors[label]
        currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=2))
        currentAxis.text(xmin, ymin, display_txt, bbox={'facecolor':color, 'alpha':0.5})
    
    plt.show()
